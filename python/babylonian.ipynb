# %%
import trimesh
import babylonian

# %%
mesh = trimesh.load("../../../PhenomicsLabs/backups/alignedRegisteredMeshes2/130101010417.obj", force="mesh")
babylonian.plot3d(mesh, color="#d97706")
# Out:
# /Users/jovid/miniconda3/envs/babylonian/lib/python3.12/site-packages/IPython/core/display.py:447: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe style='width:100%; max-width:900px; aspect-ratio:900 / 700; height:auto; border:0; display:block;' sandbox='allow-scripts allow-same-origin' src="data:text/html;base64,..."></iframe>
